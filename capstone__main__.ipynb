# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Setting the current working directory

import os; 
os.chdir('/content/drive/MyDrive/Colab Notebooks/Capstone/Final')

# %%
from sklearn.model_selection import train_test_split
#from text_preprocess import *
from capstone_preprocess import *
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
'''from sklearn.base import BaseEstimator,TransformerMixin
import pandas as pd
class ColumnsLabelEncoder(BaseEstimator, TransformerMixin):
      
    def __init__(self, variables=None):
        
        if not isinstance(variables, list):
            self.variables = [variables]
        else:
            self.variables = variables

    def fit(self, X, y=None):
        # we need this step to fit the sklearn pipeline
        return self

    def transform(self, X):
        X = X.copy()
       
        country = {'Country_01':1,'Country_02':2,'Country_03':3}
      
        local = { 'Local_01': 1,
                  'Local_02': 2,
                  'Local_03': 3,
                  'Local_04': 4,
                  'Local_05': 5,
                  'Local_06': 6,
                  'Local_07': 7,
                  'Local_08': 8,
                  'Local_09': 9,
                  'Local_10': 10,
                  'Local_11': 11,
                  'Local_12': 12 }

        emp = {
                  'Third Party': 1,
                  'Employee': 2,
                  'Third Party (Remote)': 3
        }
        
        risk_grade = {'I':1,'II':2,'III':3,'IV':4,'V':5,'VI':6}        
        

        X['Countries'] = pd.Series([country[x] for x in X['Countries']], index=X.index)
        #print('Countries Encoded')

        X['Local'] = pd.Series([local[x] for x in X['Local']], index=X.index)
        #print('Local Encoded')

        X['Emp_Type'] = pd.Series([emp[x] for x in X['Emp_Type']], index=X.index)
        #print('Emp_type Encoded')

        X['Potential_Accident'] = pd.Series([risk_grade[x] for x in data['Potential_Accident']], index=data.index)
        #print('Potential Accident Encoded')

       # X['Gender'] = pd.Series([country[x] for x in X['Gender']], index=X.index)
      #  X=X.loc[:,enc_attribs]
       #print("enc Dateframe chk",X.head())
       #print("###############################X.shape:",X.shape)
       ##print("###############################X.head:",X[0,:])
        return X'''
# Out:
# 'from sklearn.base import BaseEstimator,TransformerMixin\nimport pandas as pd\nclass ColumnsLabelEncoder(BaseEstimator, TransformerMixin):\n      \n    def __init__(self, variables=None):\n        \n        if not isinstance(variables, list):\n            self.variables = [variables]\n        else:\n            self.variables = variables\n\n    def fit(self, X, y=None):\n        # we need this step to fit the sklearn pipeline\n        return self\n\n    def transform(self, X):\n        X = X.copy()\n       \n        country = {\'Country_01\':1,\'Country_02\':2,\'Country_03\':3}\n      \n        local = { \'Local_01\': 1,\n                  \'Local_02\': 2,\n                  \'Local_03\': 3,\n                  \'Local_04\': 4,\n                  \'Local_05\': 5,\n                  \'Local_06\': 6,\n                  \'Local_07\': 7,\n                  \'Local_08\': 8,\n                  \'Local_09\': 9,\n                  \'Local_10\': 10,\n                  \'Local_11\': 11,\n                  \'Local_12\': 12 }\n\n        emp = {\n                  \'Third Party\': 1,\n                  \'Employee\': 2,\n                  \'Third Party (Remote)\': 3\n        }\n        \n        risk_grade = {\'I\':1,\'II\':2,\'III\':3,\'IV\':4,\'V\':5,\'VI\':6}        \n        \n\n        X[\'Countries\'] = pd.Series([country[x] for x in X[\'Countries\']], index=X.index)\n        #print(\'Countries Encoded\')\n\n        X[\'Local\'] = pd.Series([local[x] for x in X[\'Local\']], index=X.index)\n        #print(\'Local Encoded\')\n\n        X[\'Emp_Type\'] = pd.Series([emp[x] for x in X[\'Emp_Type\']], index=X.index)\n        #print(\'Emp_type Encoded\')\n\n        X[\'Potential_Accident\'] = pd.Series([risk_grade[x] for x in data[\'Potential_Accident\']], index=data.index)\n        #print(\'Potential Accident Encoded\')\n\n       # X[\'Gender\'] = pd.Series([country[x] for x in X[\'Gender\']], index=X.index)\n      #  X=X.loc[:,enc_attribs]\n       #print("enc Dateframe chk",X.head())\n       #print("###############################X.shape:",X.shape)\n       ##print("###############################X.head:",X[0,:])\n        return X'

# %%
import pandas as pd
#ram 
data = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Capstone/IHMStefanini_industrial_safety_and_health_database_with_accidents_description_Dataset_SMOTE.csv")
#satya path /content/drive/MyDrive/Capstone project/IHMStefanini_industrial_safety_and_health_database_with_accidents_description.csv
#data = pd.read_csv("/content/drive/MyDrive/Capstone project/IHMStefanini_industrial_safety_and_health_database_with_accidents_description.csv")
data.head(3)
# Out:
#    Unnamed: 0  ... Accident Level
# 0           0  ...              I
# 1           1  ...              I
# 2           2  ...              I
#
# [3 rows x 11 columns]

# %%
data_bkp = data.copy()

# %%
data.rename(columns=
            {'Data':'Date','Genre':'Gender','Industry Sector':'Industry','Accident Level':'Accident','Potential Accident Level':'Potential_Accident','Employee or Third Party':'Emp_Type','Critical Risk':'Critical Risk'},inplace=True)

# %%
data
# Out:
#       Unnamed: 0  ... Accident
# 0              0  ...        I
# 1              1  ...        I
# 2              2  ...        I
# 3              3  ...        I
# 4              4  ...       IV
# ...          ...  ...      ...
# 1575        1575  ...        V
# 1576        1576  ...        V
# 1577        1577  ...        V
# 1578        1578  ...        V
# 1579        1579  ...        V
#
# [1580 rows x 11 columns]

# %% [markdown]
# ## Target

# %%
risk_grade = {'I':0,'II':1,'III':2,'IV':3,'V':4,'VI':5}
data['Accident'] = pd.Series([risk_grade[x] for x in data['Accident']], index=data.index)

# %%
y=data['Accident']

# %%
data_x = data.drop(columns ='Accident',axis =1)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    data_x, y, 
    test_size=0.2, random_state=1)

# %%
X_train, X_val, y_train, y_val = train_test_split(
    X_train, y_train, 
    test_size=0.14, random_state=0)

# %%
print(X_train.shape,y_train.shape,X_val.shape,y_val.shape,X_test.shape,y_test.shape)
# Out:
# (1087, 10) (1087,) (177, 10) (177,) (316, 10) (316,)

# %%
import pickle
filename = 'capstone_NLP_chatbot.pkl'

# %%
svm_model = pickle.load(open(filename, 'rb'))
print(svm_model)
result = svm_model.predict(X_test)
print(result)
# Out:
# Pipeline(memory=None,
#          steps=[('data_transaform',
#                  ColumnTransformer(n_jobs=None, remainder='drop',
#                                    sparse_threshold=0.3,
#                                    transformer_weights=None,
#                                    transformers=[('datetransform',
#                                                   Pipeline(memory=None,
#                                                            steps=[('date_info_split',
#                                                                    TemporalVariableEstimator(variables=['Date']))],
#                                                            verbose=False),
#                                                   ['Date']),
#                                                  ('imputer',
#                                                   Pipeline(memory=None,
#                                                            steps=[('risk_imputer',
#                                                                    Impu...
#                  PCA(copy=True, iterated_power='auto', n_components=45,
#                      random_state=None, svd_solver='auto', tol=0.0,
#                      whiten=False)),
#                 ('SVC',
#                  SVC(C=0.05770301272014699, break_ties=False, cache_size=200,
#                      class_weight=None, coef0=0.0,
#                      decision_function_shape='ovr', degree=3,
#                      gamma=3.2346364044821243, kernel='linear', max_iter=-1,
#                      probability=False, random_state=42, shrinking=True,
#                      tol=0.001, verbose=False))],
#          verbose=False)
# /usr/local/lib/python3.6/dist-packages/sklearn/base.py:197: FutureWarning: From version 0.24, get_params will raise an AttributeError if a parameter cannot be retrieved as an instance attribute. Previously it would return None.
#   FutureWarning)
# /content/drive/MyDrive/Colab Notebooks/Capstone/Final/capstone_preprocess.py:164: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.new_col_name= df[col].apply(lambda x : x.lower())
# [2 3 4 1 1 4 0 2 2 0 1 0 4 4 2 1 1 1 2 0 4 0 3 2 0 2 4 4 0 3 0 1 3 3 1 2 1
#  0 3 3 3 1 1 1 2 3 4 4 4 1 0 0 3 4 0 4 1 4 0 2 3 4 2 4 4 4 4 4 1 2 1 3 3 2
#  3 0 4 4 3 4 4 1 3 3 0 2 2 0 0 2 0 0 3 3 4 0 0 1 1 0 0 2 1 1 0 4 1 4 2 2 3
#  4 3 0 4 4 2 2 2 4 3 3 1 3 2 0 2 3 1 1 3 0 2 4 1 4 1 4 2 2 2 3 4 2 0 4 0 1
#  3 1 4 3 2 3 2 2 3 0 1 4 2 1 3 2 1 4 2 4 3 0 3 2 3 1 0 0 3 4 0 3 4 4 4 0 4
#  4 3 4 4 4 2 0 3 1 3 1 0 3 0 0 2 1 2 2 2 0 1 2 4 2 4 0 1 1 1 3 4 1 3 4 4 3
#  3 3 4 0 4 1 0 1 1 0 3 1 3 4 4 2 4 2 2 0 2 2 3 0 3 3 4 3 4 3 3 4 4 4 2 4 3
#  4 3 1 0 2 2 2 2 1 2 4 4 0 3 2 4 3 3 4 3 1 1 4 4 2 4 3 4 0 4 1 3 2 4 2 2 4
#  0 1 2 2 3 1 3 2 2 3 2 4 4 4 2 0 2 2 4 1]

# %%
test = pd.DataFrame()
test.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
#test = pd.DataFrame()
# df.append([df_try]*5,ignore_index=True)
test=test.append([X_test[0:1]]*50,ignore_index=True)
svm_model.predict(test)[0]
# Out:
# /content/drive/MyDrive/Colab Notebooks/Capstone/Final/capstone_preprocess.py:164: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.new_col_name= df[col].apply(lambda x : x.lower())
# /usr/local/lib/python3.6/dist-packages/sklearn/decomposition/_pca.py:456: RuntimeWarning: invalid value encountered in true_divide
#   explained_variance_ratio_ = explained_variance_ / total_var
# /usr/local/lib/python3.6/dist-packages/sklearn/decomposition/_pca.py:456: RuntimeWarning: invalid value encountered in true_divide
#   explained_variance_ratio_ = explained_variance_ / total_var
# 2

# %%
test.head()
# Out:
#    Unnamed: 0  ...                                        Description
# 0         553  ...  Employee reports that he performed an activity...
# 1         553  ...  Employee reports that he performed an activity...
# 2         553  ...  Employee reports that he performed an activity...
# 3         553  ...  Employee reports that he performed an activity...
# 4         553  ...  Employee reports that he performed an activity...
#
# [5 rows x 10 columns]

# %%
X_test[0:1]
# Out:
#      Unnamed: 0  ...                                        Description
# 553         553  ...  Employee reports that he performed an activity...
#
# [1 rows x 10 columns]

# %%
# load json and create lstm_pred_model
from keras.models import model_from_json
json_file = open('lstm_pred_model.json', 'r')
loaded_lstm_pred_model_json = json_file.read()
json_file.close()
loaded_lstm_pred_model = model_from_json(loaded_lstm_pred_model_json)
# load weights into new lstm_pred_model
loaded_lstm_pred_model.load_weights("lstm_pred_model.h5")
print("Loaded lstm_pred_model from disk")
# Out:
# Loaded lstm_pred_model from disk

# %%
lstm_pred_model = pickle.load(open('lstm_xgb_lstm_full_model.pkl', 'rb'))
#lstm_pred = lstm_pred_model.predict(X_test)
print(lstm_pred_model)
# Out:
# Pipeline(memory=None,
#          steps=[('lstm_full_pipeline',
#                  ColumnTransformer(n_jobs=None, remainder='drop',
#                                    sparse_threshold=0.3,
#                                    transformer_weights=None,
#                                    transformers=[('datetransform',
#                                                   Pipeline(memory=None,
#                                                            steps=[('date_info_split',
#                                                                    TemporalVariableEstimator(variables=['Date']))],
#                                                            verbose=False),
#                                                   ['Date']),
#                                                  ('imputer',
#                                                   Pipeline(memory=None,
#                                                            steps=[('risk_imputer',
#                                                                    I...
#                  XGBClassifier(base_score=0.5, booster='gbtree',
#                                colsample_bylevel=1, colsample_bynode=1,
#                                colsample_bytree=1, eta=0.003, gamma=0,
#                                learning_rate=0.04, max_delta_step=0,
#                                max_depth=7, min_child_weight=3, missing=nan,
#                                n_estimators=100, n_jobs=1, nthread=None,
#                                objective='multi:softprob', random_state=42,
#                                reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#                                seed=None, silent=None, subsample=1,
#                                verbosity=1))],
#          verbose=False)
# /usr/local/lib/python3.6/dist-packages/sklearn/base.py:197: FutureWarning: From version 0.24, get_params will raise an AttributeError if a parameter cannot be retrieved as an instance attribute. Previously it would return None.
#   FutureWarning)

# %%
lstm_pred_model.predict(test)[0]
# Out:
# /content/drive/MyDrive/Colab Notebooks/Capstone/Final/capstone_preprocess.py:164: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.new_col_name= df[col].apply(lambda x : x.lower())
# /usr/local/lib/python3.6/dist-packages/sklearn/decomposition/_pca.py:456: RuntimeWarning: invalid value encountered in true_divide
#   explained_variance_ratio_ = explained_variance_ / total_var
# /usr/local/lib/python3.6/dist-packages/sklearn/decomposition/_pca.py:456: RuntimeWarning: invalid value encountered in true_divide
#   explained_variance_ratio_ = explained_variance_ / total_var
# /content/drive/MyDrive/Colab Notebooks/Capstone/Final/capstone_preprocess.py:164: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.new_col_name= df[col].apply(lambda x : x.lower())
# Loaded lstm_pred_model from disk
# 2

# %%
#Stacking

from sklearn.ensemble import GradientBoostingClassifier
from sklearn.linear_model import LassoCV
from sklearn.ensemble import StackingClassifier 
from sklearn.naive_bayes import GaussianNB

estimators = [('SVM', svm_model),
              ('lstm', lstm_pred_model)
            #   ('NB', nb_model),
            #   ('RF', rf_best_model),
            # #  ('Bagging', bgcl_best_model),
            # #('AdaBoost', ada_best_model),
            # ('XGBoost', xgb_best_model)
            ]

stack_clf = StackingClassifier(estimators=estimators, final_estimator=GaussianNB())
                               
                              #  ,final_estimator_= None,
                              #   #final_estimator=lstm_pred_model,
                              #   #cv=5,
                              #   stack_method='auto')

#stack_clf.fit(X_train,y_train)
y_train_pred = stack_clf.predict(x_train)
print("____________________________Confusion Matrix for Stacking for Train Data____________________________")
print(confusion_matrix(y_train, y_train_pred))
print(classification_report(y_train, y_train_pred, labels=[1, 0]))
print("____________________________________________________________________________________")
y_val_pred = stack_clf.predict(X_val)
print("____________________________Confusion Matrix for Stacking for Val data____________________________")
print(confusion_matrix(y_val, y_val_pred))
print(classification_report(y_val, y_val_pred, labels=[1, 0]))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-bef206e2d515> in <module>()
#      23
#      24 #stack_clf.fit(X_train,y_train)
# ---> 25 y_train_pred = stack_clf.predict(x_train)
#      26 print("____________________________Confusion Matrix for Stacking for Train Data____________________________")
#      27 print(confusion_matrix(y_train, y_train_pred))
#
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/metaestimators.py in __get__(self, obj, type)
#     111                     break
#     112             else:
# --> 113                 attrgetter(self.delegate_names[-1])(obj)
#     114
#     115         # lambda, but not partial, allows help() to work with update_wrapper
#
# AttributeError: 'StackingClassifier' object has no attribute 'final_estimator_'
